# %%
# Load env variables and create client
from anthropic import Anthropic
from dotenv import load_dotenv

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a solution to parse an S3 bucket name from an S3 URI:\n\n## Simple Solution\n\n```python\ndef parse_s3_bucket(s3_uri):\n    \"\"\"\n    Parse bucket name from an S3 URI.\n    \n    Args:\n        s3_uri (str): S3 URI in format s3://bucket-name/path/to/file\n        \n    Returns:\n        str: The bucket name\n        \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n    \"\"\"\n    if not s3_uri.startswith('s3://'):\n        raise ValueError(\"Invalid S3 URI: must start with 's3://'\")\n    \n    # Remove 's3://' prefix and split by '/'\n    path = s3_uri[5:]  # Remove 's3://'\n    bucket_name = path.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(\"Invalid S3 URI: bucket name is empty\")\n    \n    return bucket_name\n\n\n# Test cases\nprint(parse_s3_bucket(\"s3://my-bucket/path/to/file.txt\"))  # my-bucket\nprint(parse_s3_bucket(\"s3://another-bucket/\"))              # another-bucket\nprint(parse_s3_bucket(\"s3://bucket\"))                       # bucket\n```\n\n## Robust Solution (with regex)\n\n```python\nimport re\n\ndef parse_s3_bucket_robust(s3_uri):\n    \"\"\"\n    Parse bucket name from an S3 URI using regex.\n    \n    Args:\n        s3_uri (str): S3 URI in format s3://bucket-name/path/to/file\n        \n    Returns:\n        str: The bucket name\n        \n    Raises:\n        ValueError: If the URI is not a valid S3 URI\n    \"\"\"\n    pattern = r's3://([a-z0-9][a-z0-9.\\-]*[a-z0-9])(?:/.*)?$'\n    match = re.match(pattern, s3_uri, re.IGNORECASE)\n    \n    if not match:\n        raise ValueError(f\"Invalid S3 URI: {s3_uri}\")\n    \n    return match.group(1)\n\n\n# Test cases\nprint(parse_s3_bucket_robust(\"s3://my-bucket/path/to/file.txt\"))  # my-bucket\nprint(parse_s3_bucket_robust(\"s3://bucket-123/\"))                  # bucket-123\n```\n\n## Using urllib.parse\n\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_bucket_urllib(s3_uri):\n    \"\"\"\n    Parse bucket name from an S3 URI using urllib.\n    \n    Args:\n        s3_uri (str): S3 URI in format s3://bucket-name/path/to/file\n        \n    Returns:\n        str: The bucket name\n    \"\"\"\n    parsed = urlparse(s3_uri)\n    \n    if parsed.scheme != 's3':\n        raise ValueError(\"Invalid S3 URI: must use 's3://' scheme\")\n    \n    if not parsed.netloc:\n        raise ValueError(\"Invalid S3 URI: bucket name is missing\")\n    \n    return parsed.netloc\n\n\n# Test cases\nprint(parse_s3_bucket_urllib(\"s3://my-bucket/path/to/file.txt\"))  # my-bucket\n```\n\n## Comparison\n\n| Method | Pros | Cons |\n|--------|------|------|\n| **Simple (string split)** | Fast, minimal dependencies | Less validation |\n| **Regex** | Validates bucket name format | Slightly slower |\n| **urllib** | Standard library, clean | More overhead |\n\n**Recommendation**: Use the **simple solution** for basic needs, or the **regex solution** if you need to validate bucket name format according to AWS rules.",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., s3://my-bucket/path/to/file.txt)",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution effectively demonstrates multiple valid approaches with appropriate trade-offs and good documentation. However, the regex validation isn't fully compliant with AWS S3 bucket naming conventions, and the simple solution lacks validation entirely. The urllib approach is the most robust for basic parsing but the solution doesn't adequately address S3's various URI formats that exist in real-world AWS usage."
#   },
#   {
#     "output": "# AWS Lambda CloudFormation Template\n\nHere's a complete JSON CloudFormation template that defines a simple AWS Lambda function with a basic execution role:\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for a simple AWS Lambda function with basic execution role\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ],\n        \"RoleName\": \"SimpleLambdaExecutionRole\"\n      }\n    },\n    \"SimpleLambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"SimpleLambdaFunction\",\n        \"Runtime\": \"python3.11\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Handler\": \"index.lambda_handler\",\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello from Lambda!'\\n    }\\n\"\n        },\n        \"Description\": \"A simple Lambda function for testing\",\n        \"Timeout\": 30,\n        \"MemorySize\": 128\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"SimpleLambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaFunctionName\": {\n      \"Description\": \"Name of the Lambda function\",\n      \"Value\": {\n        \"Ref\": \"SimpleLambdaFunction\"\n      }\n    },\n    \"ExecutionRoleArn\": {\n      \"Description\": \"ARN of the Lambda execution role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"LambdaExecutionRole\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Template Components Explained\n\n### 1. **LambdaExecutionRole** (IAM Role)\n- **AssumeRolePolicyDocument**: Allows Lambda service to assume this role\n- **ManagedPolicyArns**: Attaches the AWS managed policy for basic Lambda execution (CloudWatch Logs permissions)\n- **RoleName**: User-friendly name for the role\n\n### 2. **SimpleLambdaFunction** (Lambda Function)\n- **Runtime**: Python 3.11 (can be changed to nodejs, java, etc.)\n- **Role**: References the execution role created above\n- **Handler**: Entry point for the function (index.lambda_handler)\n- **Code**: Inline Python code that returns a simple response\n- **Timeout**: 30 seconds (maximum execution time)\n- **MemorySize**: 128 MB\n\n### 3. **Outputs**\nProvides useful information after stack creation:\n- Lambda function ARN\n- Lambda function name\n- Execution role ARN\n\n## How to Deploy\n\n```bash\naws cloudformation create-stack \\\n  --stack-name simple-lambda-stack \\\n  --template-body file://template.json\n```\n\n## To View Stack Status\n\n```bash\naws cloudformation describe-stacks \\\n  --stack-name simple-lambda-stack\n```\n\nThis template is production-ready and follows AWS best practices!",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template that defines a simple AWS Lambda function with basic execution role",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The template correctly fulfills the core requirements with valid JSON syntax, proper IAM role with assume policy, and a working Lambda function with inline code. Documentation and outputs are well-structured. However, the hardcoded RoleName violates CloudFormation best practices and could cause deployment issues. The 'production-ready' claim is overstated for a basic template lacking enterprise-grade considerations. Overall, this is a solid educational example but has a meaningful implementation flaw and misleading marketing language."
#   },
#   {
#     "output": "# AWS IAM Role ARN Validator\n\nHere's a comprehensive solution:\n\n```python\nimport re\nfrom typing import Union\n\ndef validate_iam_role_arn(arn: Union[str, None]) -> bool:\n    \"\"\"\n    Validates an AWS IAM role ARN format.\n    \n    Valid IAM role ARN format:\n    arn:aws:iam::{account-id}:role/{role-name}\n    \n    Args:\n        arn: The ARN string to validate\n        \n    Returns:\n        bool: True if valid IAM role ARN, False otherwise\n        \n    Examples:\n        >>> validate_iam_role_arn(\"arn:aws:iam::123456789012:role/my-role\")\n        True\n        >>> validate_iam_role_arn(\"arn:aws:iam::123456789012:role/my-role-with-path/sub-path\")\n        True\n        >>> validate_iam_role_arn(\"arn:aws:iam::123456789012:user/my-user\")\n        False\n        >>> validate_iam_role_arn(\"invalid-arn\")\n        False\n    \"\"\"\n    \n    # Check if input is a string\n    if not isinstance(arn, str):\n        return False\n    \n    # Strip whitespace\n    arn = arn.strip()\n    \n    # IAM role ARN pattern\n    # Pattern explanation:\n    # ^arn:aws:iam:: - starts with arn:aws:iam::\n    # \\d{12} - exactly 12 digits for account ID\n    # :role\\/ - literal :role/\n    # [\\w+=,.@-]{1,64}(\\/[\\w+=,.@-]{1,64})* - role name and optional path components\n    # $ - end of string\n    \n    pattern = r\"^arn:aws:iam::\\d{12}:role\\/[\\w+=,.@-]{1,64}(\\/[\\w+=,.@-]{1,64})*$\"\n    \n    return bool(re.match(pattern, arn))\n\n\n# Alternative more strict version (without path support)\ndef validate_iam_role_arn_simple(arn: Union[str, None]) -> bool:\n    \"\"\"\n    Simpler version that validates basic IAM role ARN format without path support.\n    \"\"\"\n    if not isinstance(arn, str):\n        return False\n    \n    pattern = r\"^arn:aws:iam::\\d{12}:role\\/[\\w+=,.@-]+$\"\n    return bool(re.match(pattern, arn))\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # Valid ARNs\n        (\"arn:aws:iam::123456789012:role/my-role\", True),\n        (\"arn:aws:iam::123456789012:role/MyRole\", True),\n        (\"arn:aws:iam::123456789012:role/my-role-123\", True),\n        (\"arn:aws:iam::123456789012:role/my.role\", True),\n        (\"arn:aws:iam::123456789012:role/my_role\", True),\n        (\"arn:aws:iam::123456789012:role/my+role\", True),\n        (\"arn:aws:iam::123456789012:role/my@role\", True),\n        (\"arn:aws:iam::123456789012:role/path/to/my-role\", True),\n        (\"arn:aws:iam::999999999999:role/admin\", True),\n        \n        # Invalid ARNs\n        (\"arn:aws:iam::123456789012:user/my-user\", False),  # user, not role\n        (\"arn:aws:iam::123456789012:role\", False),  # missing role name\n        (\"arn:aws:iam::12345678901:role/my-role\", False),  # 11 digits instead of 12\n        (\"arn:aws:iam::1234567890123:role/my-role\",",
#     "test_case": {
#       "task": "Write a Python function that validates an AWS IAM role ARN format and returns True/False",
#       "format": "python"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates strong software engineering practices with clear documentation and thoughtful design. However, it has a critical regex pattern flaw that could cause false negatives for valid IAM role ARNs with multi-segment paths, and the incomplete test cases suggest the code wasn't fully validated. The core approach is sound, but the implementation needs refinement to be production-ready."
#   }
# ]
