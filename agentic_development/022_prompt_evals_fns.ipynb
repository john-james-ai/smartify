# %%
# Load env variables and create client
from anthropic import Anthropic
from dotenv import load_dotenv

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import ast
import re


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.5

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef parse_s3_bucket(uri):\n    match = re.match(r's3://([^/]+)', uri)\n    return match.group(1) if match else None\n\n# Test\nprint(parse_s3_bucket('s3://my-bucket-name/path/to/object'))\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI like 's3://my-bucket-name/path/to/object'",
#       "format": "regex"
#     },
#     "score": 8.5,
#     "reasoning": "The solution correctly solves the stated task using an appropriate regex pattern. However, it lacks robustness for production use due to missing input validation and incomplete test coverage. The function would fail if passed None or non-string types. Adding a simple guard clause and more comprehensive tests would significantly improve reliability."
#   },
#   {
#     "output": "\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for AWS Lambda function with basic execution role\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"LambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"MyLambdaFunction\",\n        \"Runtime\": \"python3.11\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Handler\": \"index.lambda_handler\",\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello from Lambda!'\\n    }\\n\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"LambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaExecutionRoleArn\": {\n      \"Description\": \"ARN of the Lambda execution role\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"LambdaExecutionRole\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template for an AWS Lambda function with basic execution role",
#       "format": "json"
#     },
#     "score": 8.5,
#     "reasoning": "The template successfully delivers the core requirement of a Lambda function with basic execution role. The IAM configuration is correct and follows AWS best practices by using the AWSLambdaBasicExecutionRole managed policy. However, the solution lacks flexibility and depth expected in a production-ready CloudFormation template. The hardcoded function name and overly minimal code example reduce practical applicability. Including parameters, environment variables, and timeout configuration would significantly improve the template's reusability and demonstrate better CloudFormation patterns."
#   },
#   {
#     "output": "\nimport json\nfrom typing import List, Dict, Any\n\ndef convert_iam_policy_to_readable(policy_json: str) -> str:\n    \"\"\"\n    Convert an AWS IAM policy JSON string into a human-readable format.\n    \n    Args:\n        policy_json: A JSON string representing an IAM policy\n        \n    Returns:\n        A human-readable string representation of the policy\n    \"\"\"\n    policy = json.loads(policy_json)\n    readable_output = []\n    \n    if \"Statement\" in policy:\n        for i, statement in enumerate(policy[\"Statement\"], 1):\n            readable_output.append(f\"Statement {i}:\")\n            \n            effect = statement.get(\"Effect\", \"Not specified\")\n            readable_output.append(f\"  Effect: {effect}\")\n            \n            actions = statement.get(\"Action\", [])\n            if isinstance(actions, str):\n                actions = [actions]\n            readable_output.append(f\"  Action:\")\n            for action in actions:\n                readable_output.append(f\"    - {action}\")\n            \n            resources = statement.get(\"Resource\", [])\n            if isinstance(resources, str):\n                resources = [resources]\n            readable_output.append(f\"  Resource:\")\n            for resource in resources:\n                readable_output.append(f\"    - {resource}\")\n            \n            readable_output.append(\"\")\n    \n    return \"\\n\".join(readable_output)\n\n\nif __name__ == \"__main__\":\n    sample_policy = \"\"\"{\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Action\": [\n                    \"s3:GetObject\",\n                    \"s3:ListBucket\"\n                ],\n                \"Resource\": [\n                    \"arn:aws:s3:::my-bucket\",\n                    \"arn:aws:s3:::my-bucket/*\"\n                ]\n            },\n            {\n                \"Effect\": \"Deny\",\n                \"Action\": \"iam:*\",\n                \"Resource\": \"*\"\n            }\n        ]\n    }\"\"\"\n    \n    result = convert_iam_policy_to_readable(sample_policy)\n    print(result)\n",
#     "test_case": {
#       "task": "Write a Python function that converts an AWS IAM policy JSON string into a human-readable format by extracting the Effect, Action, and Resource fields",
#       "format": "python"
#     },
#     "score": 8.5,
#     "reasoning": "The solution successfully addresses the core requirement of extracting and formatting Effect, Action, and Resource fields. It demonstrates good programming practices with type hints and proper handling of field value variations. However, it lacks robustness for edge cases and doesn't support the full range of IAM policy types. The solution works well for basic identity-based policies but would fail silently or incompletely on resource-based policies or policies with conditional logic."
#   }
# ]
